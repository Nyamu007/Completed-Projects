# %% [markdown]
# # Robotics, Vision & Control 3e: for Python
# ## Chapter 6: Localization and Mapping
#
# Copyright (c) 2021- Peter Corke

# %%
try:
    import google.colab
    print('Running on CoLab')
    COLAB = True
    #!pip install roboticstoolbox-python>=1.0.2
    # !pip install git+https://github.com/petercorke/robotics-toolbox-python@future
    # !pip install spatialmath-python>=1.1.5
    # !pip install --no-deps rvc3python
except ModuleNotFoundError:
    COLAB = False

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"
from IPython.display import HTML

import matplotlib.pyplot as plt

# add RTB examples folder to the path
import sys, os.path
import RVC3 as rvc
sys.path.append(os.path.join(rvc.__path__[0], 'models'))

# ------ standard imports ------ #
import numpy as np
import math
from math import pi
np.set_printoptions(
    linewidth=120, formatter={
        'float': lambda x: f"{0:8.4g}" if abs(x) < 1e-10 else f"{x:8.4g}"})
np.random.seed(0)
from spatialmath import *
from spatialmath.base import *
from roboticstoolbox import *
# Out:
# Running on CoLab
# Collecting git+https://github.com/petercorke/robotics-toolbox-python@future
#   Cloning https://github.com/petercorke/robotics-toolbox-python (to revision future) to /tmp/pip-req-build-8klprrsx
#   Running command git clone --filter=blob:none --quiet https://github.com/petercorke/robotics-toolbox-python /tmp/pip-req-build-8klprrsx
#   Running command git checkout -b future --track origin/future
#   Switched to a new branch 'future'
#   Branch 'future' set up to track remote branch 'future' from 'origin'.
#   Resolved https://github.com/petercorke/robotics-toolbox-python to commit 6188446a943f6c4d830b4d79b0a36b45cd3e7084
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.26.4)
# Requirement already satisfied: spatialmath-python>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.1.15)
# Requirement already satisfied: spatialgeometry>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.1.0)
# Requirement already satisfied: pgraph-python in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (0.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (3.10.0)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (0.11.4)
# Requirement already satisfied: swift-sim>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.1.0)
# Requirement already satisfied: rtb-data in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.0.1)
# Requirement already satisfied: progress in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.6.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (4.15.0)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (4.5.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.12/dist-packages (from swift-sim>=1.0.0->roboticstoolbox-python==1.2.0) (15.0.1)
# Requirement already satisfied: colored in /usr/local/lib/python3.12/dist-packages (from ansitable->roboticstoolbox-python==1.2.0) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->roboticstoolbox-python==1.2.0) (1.17.0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (20.35.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.2.0) (4.5.0)
# Requirement already satisfied: rvc3python in /usr/local/lib/python3.12/dist-packages (0.9.2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2149884612.py in <cell line: 0>()
#      28     linewidth=120, formatter={
#      29         'float': lambda x: f"{0:8.4g}" if abs(x) < 1e-10 else f"{x:8.4g}"})
# ---> 30 np.random.seed(0)
#      31 from spatialmath import *
#      32 from spatialmath.base import *
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     335
#     336     def __dir__():
# --> 337         public_symbols = globals().keys() | {'testing'}
#     338         public_symbols -= {
#     339             "core", "matrixlib",
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/__init__.py in <module>
#     178
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/_pickle.py in <module>
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#       4 from ._sfc64 import SFC64
#       5
#
# numpy/random/mtrand.pyx in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# !pip install numpy==1.26.4
# !pip install spatialmath-python==1.1.5
# !pip install swift-sim==1.1.0
# !pip install spatialgeometry==1.1.0
# !pip install git+https://github.com/petercorke/robotics-toolbox-python@future --no-build-isolation
# !pip install --no-deps rvc3python
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Collecting spatialmath-python==1.1.5
#   Downloading spatialmath_python-1.1.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.12/dist-packages (from spatialmath-python==1.1.5) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from spatialmath-python==1.1.5) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from spatialmath-python==1.1.5) (3.10.0)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.12/dist-packages (from spatialmath-python==1.1.5) (0.11.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from spatialmath-python==1.1.5) (4.15.0)
# Requirement already satisfied: colored in /usr/local/lib/python3.12/dist-packages (from ansitable->spatialmath-python==1.1.5) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python==1.1.5) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->spatialmath-python==1.1.5) (1.17.0)
# Downloading spatialmath_python-1.1.5-py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.2/186.2 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: spatialmath-python
#   Attempting uninstall: spatialmath-python
#     Found existing installation: spatialmath-python 1.1.15
#     Uninstalling spatialmath-python-1.1.15:
#       Successfully uninstalled spatialmath-python-1.1.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rvc3python 0.9.2 requires bdsim>=1.1, which is not installed.
# rvc3python 0.9.2 requires machinevision-toolbox-python, which is not installed.
# rvc3python 0.9.2 requires pybullet, which is not installed.
# Successfully installed spatialmath-python-1.1.5
# Requirement already satisfied: swift-sim==1.1.0 in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.12/dist-packages (from swift-sim==1.1.0) (1.26.4)
# Requirement already satisfied: spatialgeometry>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from swift-sim==1.1.0) (1.1.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.12/dist-packages (from swift-sim==1.1.0) (15.0.1)
# Requirement already satisfied: spatialmath-python>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spatialgeometry>=1.0.0->swift-sim==1.1.0) (1.1.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (3.10.0)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (0.11.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (4.15.0)
# Requirement already satisfied: colored in /usr/local/lib/python3.12/dist-packages (from ansitable->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->spatialmath-python>=1.0.0->spatialgeometry>=1.0.0->swift-sim==1.1.0) (1.17.0)
# Requirement already satisfied: spatialgeometry==1.1.0 in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: spatialmath-python>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spatialgeometry==1.1.0) (1.1.5)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (3.10.0)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (0.11.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (4.15.0)
# Requirement already satisfied: colored in /usr/local/lib/python3.12/dist-packages (from ansitable->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->spatialmath-python>=1.0.0->spatialgeometry==1.1.0) (1.17.0)
# Collecting git+https://github.com/petercorke/robotics-toolbox-python@future
#   Cloning https://github.com/petercorke/robotics-toolbox-python (to revision future) to /tmp/pip-req-build-01dolodw
#   Running command git clone --filter=blob:none --quiet https://github.com/petercorke/robotics-toolbox-python /tmp/pip-req-build-01dolodw
#   Running command git checkout -b future --track origin/future
#   Switched to a new branch 'future'
#   Branch 'future' set up to track remote branch 'future' from 'origin'.
#   Resolved https://github.com/petercorke/robotics-toolbox-python to commit 6188446a943f6c4d830b4d79b0a36b45cd3e7084
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.26.4)
# Requirement already satisfied: spatialmath-python>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.1.5)
# Requirement already satisfied: spatialgeometry>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.1.0)
# Requirement already satisfied: pgraph-python in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (0.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (3.10.0)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (0.11.4)
# Requirement already satisfied: swift-sim>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.1.0)
# Requirement already satisfied: rtb-data in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.0.1)
# Requirement already satisfied: progress in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (1.6.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python==1.2.0) (4.15.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.12/dist-packages (from swift-sim>=1.0.0->roboticstoolbox-python==1.2.0) (15.0.1)
# Requirement already satisfied: colored in /usr/local/lib/python3.12/dist-packages (from ansitable->roboticstoolbox-python==1.2.0) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python==1.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->roboticstoolbox-python==1.2.0) (1.17.0)
# Requirement already satisfied: rvc3python in /usr/local/lib/python3.12/dist-packages (0.9.2)

# %%
import numpy as np
np.random.seed(0)

from roboticstoolbox import *
from spatialmath import *
from swift import Swift
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-715597695.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 np.random.seed(0)
#       3
#       4 from roboticstoolbox import *
#       5 from spatialmath import *
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     335
#     336     def __dir__():
# --> 337         public_symbols = globals().keys() | {'testing'}
#     338         public_symbols -= {
#     339             "core", "matrixlib",
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/__init__.py in <module>
#     178
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/_pickle.py in <module>
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#       4 from ._sfc64 import SFC64
#       5
#
# numpy/random/mtrand.pyx in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import os; os.kill(os.getpid(), 9)

# %%
# !pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 32.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rvc3python 0.9.2 requires bdsim>=1.1, which is not installed.
# rvc3python 0.9.2 requires machinevision-toolbox-python, which is not installed.
# rvc3python 0.9.2 requires pybullet, which is not installed.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
import os; os.kill(os.getpid(), 9)

# %%
# !pip install roboticstoolbox-python spatialmath-python swift-sim
# Out:
# Requirement already satisfied: roboticstoolbox-python in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: spatialmath-python in /usr/local/lib/python3.12/dist-packages (1.1.15)
# Requirement already satisfied: swift-sim in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (1.26.4)
# Requirement already satisfied: spatialgeometry>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (1.1.0)
# Requirement already satisfied: pgraph-python in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (0.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (3.10.0)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (0.11.4)
# Requirement already satisfied: rtb-data in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (1.0.1)
# Requirement already satisfied: progress in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (1.6.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from roboticstoolbox-python) (4.15.0)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.12/dist-packages (from spatialmath-python) (4.5.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.12/dist-packages (from swift-sim) (15.0.1)
# Requirement already satisfied: colored in /usr/local/lib/python3.12/dist-packages (from ansitable->roboticstoolbox-python) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboticstoolbox-python) (2.9.0.post0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit->spatialmath-python) (20.35.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->roboticstoolbox-python) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python) (4.5.0)

# %% [markdown]
# There are some minor code changes compared to the book. These are to support
# animations in the Jupyter environment. Animations can be made using `FuncAnimation` and
# the `widget` backend, but with Colab these can be very unsmooth.  Instead we render the
# animations to HTML5 and render them locally in the browser.

# %% [markdown]
# # 6.1 Dead Reckoning using Odometry

# %% [markdown]
# ## 6.1.1 Modeling the Robot

# %%
V = np.diag([0.02, np.deg2rad(0.5)]) ** 2;

# %%
robot = Bicycle(covar=V, animation="car")

# %%
odo = robot.step((1, 0.3))

# %%
robot.q

# %%
robot.f([0, 0, 0], odo)

# %%
robot.control = RandomPath(workspace=10)

# %%
# robot.run(T=10);

html = robot.run_animation(T=20, format="html");
HTML(html)

# %% [markdown]
# ## 6.1.2 Estimating Pose

# %%
robot.Fx([0, 0, 0], [0.5, 0.1])

# %%
x_sdev = [0.05, 0.05, np.deg2rad(0.5)];
P0 = np.diag(x_sdev) ** 2;

# %%
ekf = EKF(robot=(robot, V), P0=P0)

# %%
# ekf.run(T=20);

html = ekf.run_animation(T=20, format="html");
HTML(html)

# %%
robot.plot_xy(color="b")
ekf.plot_xy(color="r")

# %%
P150 = ekf.get_P(150)

# %%
np.sqrt(P150[0, 0])

# %%
ekf.plot_xy(color="r")
ekf.plot_ellipse(filled=True, facecolor="g", alpha=0.3)

# %%
t = ekf.get_t();
pn = ekf.get_Pnorm();
plt.plot(t, pn);

# %% [markdown]
# # 6.2 Localizing with a Landmark Map

# %%
map = LandmarkMap(20, workspace=10)

# %%
map.plot()

# %%
W = np.diag([0.1, np.deg2rad(1)]) ** 2;

# %%
sensor = RangeBearingSensor(robot=robot, map=map, covar=W,
           angle=[-pi/2, pi/2], range=4, animate=True)

# %%
z, i = sensor.reading()
# z
# i
print(f"landmark {i} at {z}")

# %%
map[15]

# %%
map = LandmarkMap(20, workspace=10);
V = np.diag([0.02, np.deg2rad(0.5)]) ** 2
robot = Bicycle(covar=V, animation="car");
robot.control = RandomPath(workspace=map, seed=0)
W = np.diag([0.1, np.deg2rad(1)]) ** 2
sensor = RangeBearingSensor(robot=robot, map=map, covar=W,
           angle=[-pi/2, pi/2], range=4, seed=0, animate=True);
P0 = np.diag([0.05, 0.05, np.deg2rad(0.5)]) ** 2;
ekf = EKF(robot=(robot, V), P0=P0, map=map, sensor=(sensor, W));

# %%
# ekf.run(T=20)
html = ekf.run_animation(T=20, format="html")
HTML(html)

# %%
map.plot()
robot.plot_xy();
ekf.plot_xy();
ekf.plot_ellipse()

# %% [markdown]
# # 6.3 Creating a Landmark Map

# %%
map = LandmarkMap(20, workspace=10, seed=0);
robot = Bicycle(covar=V, animation="car");
robot.control = RandomPath(workspace=map);
W = np.diag([0.1, np.deg2rad(1)]) ** 2
sensor = RangeBearingSensor(robot=robot, map=map, covar=W,
           range=4, angle=[-pi/2, pi/2], animate=True);
ekf = EKF(robot=(robot, None), sensor=(sensor, W));

# %%
# ekf.run(T=100);

html = ekf.run_animation(T=100, format="html")
HTML(html)

# %%
map.plot();
ekf.plot_map();
robot.plot_xy();

# %%
ekf.landmark(10)

# %%
ekf.x_est[24:26]

# %%
ekf.P_est[24:26, 24:26]

# %% [markdown]
# # 6.4 Simultaneous Localization and Mapping

# %%
map = LandmarkMap(20, workspace=10);
W = np.diag([0.1, np.deg2rad(1)]) ** 2
robot = Bicycle(covar=V, x0=(3, 6, np.deg2rad(-45)),
          animation="car");
robot.control = RandomPath(workspace=map);
W = np.diag([0.1, np.deg2rad(1)]) ** 2
sensor = RangeBearingSensor(robot=robot, map=map, covar=W,
           range=4, angle=[-pi/2, pi/2], animate=True);
P0 = np.diag([0.05, 0.05, np.deg2rad(0.5)]) ** 2;
ekf = EKF(robot=(robot, V), P0=P0, sensor=(sensor, W));

# %%
# ekf.run(T=40);

html = ekf.run_animation(T=40, format="html")
HTML(html)

# %%
map.plot();       # plot true map
robot.plot_xy();  # plot true path

# %%
ekf.plot_map();      # plot estimated landmark position
ekf.plot_ellipse();  # plot estimated covariance
ekf.plot_xy();       # plot estimated robot path

# %%
T = ekf.get_transform(map)

# %% [markdown]
# # 6.5 Pose-Graph SLAM

# %% [markdown]
# NOTE. Minor changes to ensure Jupyter pretty printing of SymPy equations.  Introduced underscore to indicate subscripting, and changed `t` to `theta`
# which is printed as $\theta$.

# %%
import sympy
xi, yi, ti, xj, yj, tj = sympy.symbols("x_i y_i theta_i x_j y_j theta_j")
xm, ym, tm = sympy.symbols("x_m y_m theta_m")
xi_e = SE2(xm, ym, tm).inv() * SE2(xi, yi, ti).inv() \
     * SE2(xj, yj, tj);
fk = sympy.Matrix(sympy.simplify(xi_e.xyt()));

# %%
Ai = sympy.simplify(fk.jacobian([xi, yi, ti]))
Ai.shape

# %%
Ai

# %%
pg = PoseGraph("data/pg1.g2o");

# %%
pg.plot();

# %%
# pg.optimize(animate=True)

pg.optimize(animate=False)
pg.plot()

# %%
pg = PoseGraph("data/killian-small.toro");

# %%
pg.plot(text=False)

# %%
pg.optimize()
pg.plot(text=False)

# %% [markdown]
# # 6.6 Sequential Monte-Carlo Localization

# %%
map = LandmarkMap(20, workspace=10);

# %%
V = np.diag([0.02, np.deg2rad(0.5)]) ** 2;
robot = Bicycle(covar=V, animation="car", workspace=map);
robot.control = RandomPath(workspace=map)

# %%
W = np.diag([0.1, np.deg2rad(1)]) ** 2;
sensor = RangeBearingSensor(robot, map, covar=W, plot=True);

# %%
R = np.diag([0.1, 0.1, np.deg2rad(1)]) ** 2;

# %%
L = np.diag([0.1, 0.1]);

# %%
pf = ParticleFilter(robot, sensor=sensor, R=R, L=L, nparticles=1000, animate=True);

# %%
# pf.run(T=10);

html = pf.run_animation(T=10, format="html");
HTML(html)

# %%
map.plot();
robot.plot_xy();

# %%
pf.plot_xy();

# %%
plt.plot(pf.get_std()[:100,:]);

# %%
pf.plot_pdf()

# %% [markdown]
# # 6.8 Application: Lidar

# %% [markdown]
# ## 6.8.1 Lidar-based Odometry

# %%
pg = PoseGraph("data/killian.g2o.zip", lidar=True);

# %%
[r, theta] = pg.scan(100);
r.shape
theta.shape

# %%
plt.clf()
plt.polar(theta, r);

# %%
p100 = pg.scanxy(100);
p101 = pg.scanxy(100);
p100.shape

# %%
T = pg.scanmatch(100, 101);
T.printline()

# %%
pg.time(101) - pg.time(100)

# %% [markdown]
# ## 6.8.2 Lidar-based Map Building

# %%
og = OccupancyGrid(workspace=[-100, 250, -100, 250], cellsize=0.1, value=np.int32(0));
pg.scanmap(og, maxrange=40)
og.plot(cmap="gray")
